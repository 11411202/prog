# %% [markdown]
# <a href="https://colab.research.google.com/github/11411202/prog/blob/main/d2_%E5%AE%B9%E5%99%A8%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 1

# %%
b='abc'

# %%
type(b)
# Out:
# str

# %%
print(b)
# Out:
# abc

# %%
input("請輸入變數c")
# Out:
# 請輸入變數caaa
# 'aaa'

# %%
c=input("請輸入變數c")
# Out:
# 請輸入變數cabcdefd

# %%
type(c)
# Out:
# str

# %%
print(c)
# Out:
# abcdefd
